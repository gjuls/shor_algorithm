# %% [markdown]
# # Average Entanglement Entropy in the QFT

# %%
#QISKIT
import qiskit.quantum_info as qi
from qiskit import Aer
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.extensions import UnitaryGate
from qiskit.visualization import array_to_latex
from qiskit.quantum_info.operators import Operator
from qiskit import execute, transpile, assemble
from qiskit.visualization import plot_histogram
from qiskit.providers.aer import AerSimulator
from qiskit.providers.aer.library import SaveDensityMatrix

#PYTHON
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
import numpy as np
import random
import math
from sympy import factorint
from numpy import linalg
from numpy import pi
from sympy import *
from random import sample

print("Import Successfully")
# Out:
# Import Successfully

# %%
def qft_dagger(n, qubits):
    qc = QuantumCircuit(n)

    size = len(qubits)
    label = 40
    #qc.barrier()
    qc.append(SaveDensityMatrix(size, label = f'pho_%.1f' % (label)), [i for i in qubits])
    #qc.barrier()
        
    for j in range(n):
        for m in range(j):
            label -= 1
            qc.cp(np.pi/float(2**(j-m)), m, j)
            #qc.barrier()
            qc.append(SaveDensityMatrix(size, label = f'pho_%.1f' % (label)), [i for i in qubits])
            #qc.barrier()
        qc.h(j)
        label -=1
        #qc.barrier()
        qc.append(SaveDensityMatrix(size, label = f'pho_%.1f' % (label)), [i for i in qubits])
        #qc.barrier()

    for qubit in range(n//2):
        qc.swap(qubit, n-qubit-1)
        label -= 1
        #qc.barrier()
        qc.append(SaveDensityMatrix(size, label = f'pho_%.1f' % (label)), [i for i in qubits])
        #qc.barrier()
        
    return qc

# %%
n = 4
data = []

tmp = 0
for i in range(2*n - 2 + 1 ):
    tmp = tmp + 2*n - i

rho_step = int(n/2 + tmp + 1)                
somma = np.zeros(rho_step)

for l in range(2*n): 

    qubit = [l] 
    qc=qft_dagger(2*n, qubit)
    qc = qc.inverse()
    qc.measure_all()
    
    aer_sim = Aer.get_backend('aer_simulator')
    t_qc = transpile(qc, aer_sim)
    qobj = assemble(t_qc)                                
    results = aer_sim.run(qobj, shots = 1).result()
    counts = results.get_counts()

    labels = []
    for i in range(len(counts)):
        labels.append(int(list(counts.keys())[i], 2))

    negativities = []
    for i in (range(rho_step)):
        density_matrix = results.data()['pho_%.1f' % (i)]
        conjugate = density_matrix.transpose()
        product = np.matmul(conjugate, density_matrix) 
        root = np.sqrt(product)
        norm = root.trace()
       
        negativities.append(qi.entropy(density_matrix))#((norm- 1)/2)
    
    data.append(negativities)

    
    qc_prova = qc
    negativities = 0
    qc = 0
    counts = 0
    results = 0
    density_matrixGIULIA = density_matrix
    density_matrix = 0
    t_qc = 0
    qobj = 0
# Out:
# C:\Users\giuli\AppData\Local\Temp\ipykernel_11756\1262517835.py:31: DeprecationWarning: The return type of saved density matrices has been changed from a `numpy.ndarray` to a `qiskit.quantum_info.DensityMatrix` as of qiskit-aer 0.10. Accessing numpy array attributes is deprecated and will result in an error in a future release. To continue using saved result objects as arrays you can explicitly cast them using  `np.asarray(object)`.
#   conjugate = density_matrix.transpose()

# %%
density_matrixGIULIA.partial_transpose()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\giuli\Desktop\tesi\PYTHON\ch5\qft_ent_partitionsSINGLE.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/giuli/Desktop/tesi/PYTHON/ch5/qft_ent_partitionsSINGLE.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> density_matrixGIULIA.partial_transpose()
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit_aer\backends\compatibility.py:102, in DensityMatrix.__getattr__(self, attr)
#     100     _deprecation_warning(self, "density matrices")
#     101     return getattr(self._data, attr)
# --> 102 return getattr(super(), attr)
#
# AttributeError: 'super' object has no attribute 'partial_transpose'

# %%
qc_prova.draw(fold =- 1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                            ┌───┐                                                                                                                                                          ░ ┌─┐
#    q_0: ─────────────────────────────────────X──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────■────────────────────────────────■──────────────────────────────■────────────────────■────────────────────■───────────────────■─────────■──────────┤ H ├──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────░─┤M├─────────────────────
#                                              │                                                                                                                                                                                                                          │                                │                              │                    │                    │          ┌───┐    │         │P(-π/2)   └───┘                                                                                                                                                          ░ └╥┘┌─┐
#    q_1: ──────────────────────X──────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────■─────────────────────────■────────────────────┼───────────■────────────────────┼──────────■───────────────────┼──────────■─────────┼──────────■─────────┼──────────┤ H ├────┼─────────■─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────░──╫─┤M├──────────────────
#                               │              │                                                                                                                                                                           │                         │                    │           │                    │          │          ┌───┐    │          │         │          │P(-π/2)  │          └───┘    │P(-π/4)                                                                                                                                                                            ░  ║ └╥┘┌─┐
#    q_2: ─────────────X────────┼──────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────■────────────────────■────────────────────┼──────────■──────────────┼──────────■─────────┼───────────┼──────────■─────────┼──────────┼──────────┤ H ├────┼──────────┼─────────┼──────────■─────────┼───────────────────■───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫─┤M├───────────────
#                      │        │              │                                                                                                                                 │                    │                    │          │        ┌───┐ │          │         │           │          │P(-π/2)  │          │          └───┘    │          │P(-π/4)  │                    │P(-π/8)                                                                                                                                                                                                ░  ║  ║ └╥┘┌─┐
#    q_3: ────X────────┼────────┼──────────────┼─────────────────────────────────────────────────────────────────────────────────────────────■────────────────────■──────────────┼──────────■─────────┼──────────■─────────┼──────────┼────────┤ H ├─┼──────────┼─────────┼───────────┼──────────■─────────┼──────────┼───────────────────┼──────────■─────────┼────────────────────■───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫──╫─┤M├────────────
#             │        │        │              │                                                                                             │                    │        ┌───┐ │          │         │          │P(-π/2)  │          │        └───┘ │          │P(-π/4)  │           │                    │          │P(-π/8)            │                    │P(-π/16)                                                                                                                                                                                                                    ░  ║  ║  ║ └╥┘┌─┐
#    q_4: ────X────────┼────────┼──────────────┼────────────────────────────────────────────────────────────────■──────────────────■─────────┼──────────■─────────┼────────┤ H ├─┼──────────┼─────────┼──────────■─────────┼──────────┼──────────────┼──────────■─────────┼───────────┼────────────────────┼──────────■───────────────────┼────────────────────■────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫──╫──╫─┤M├─────────
#                      │        │              │                                                                │          ┌───┐   │         │          │P(-π/2)  │        └───┘ │          │P(-π/4)  │                    │          │P(-π/8)       │                    │           │P(-π/16)            │                              │P(-π/32)                                                                                                                                                                                                                                         ░  ║  ║  ║  ║ └╥┘┌─┐
#    q_5: ─────────────X────────┼──────────────┼────────────────────────────────────────────■─────────■─────────┼──────────┤ H ├───┼─────────┼──────────■─────────┼──────────────┼──────────■─────────┼────────────────────┼──────────■──────────────┼────────────────────┼───────────■────────────────────┼──────────────────────────────■─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫──╫──╫──╫─┤M├──────
#                               │              │                                    ┌───┐   │         │P(-π/2)  │          └───┘   │P(-π/4)  │                    │P(-π/8)       │                    │P(-π/16)            │                         │P(-π/32)            │                                │P(-π/64)                                                                                                                                                                                                                                                                        ░  ║  ║  ║  ║  ║ └╥┘┌─┐
#    q_6: ──────────────────────X──────────────┼─────────────────────────■──────────┤ H ├───┼─────────■─────────┼──────────────────■─────────┼────────────────────■──────────────┼────────────────────■────────────────────┼─────────────────────────■────────────────────┼────────────────────────────────■────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────░──╫──╫──╫──╫──╫──╫─┤M├───
#                                              │                         │          └───┘   │                   │                            │                                   │                                         │                                              │                                                                                                                                                                                                                                                                                                                 ░  ║  ║  ║  ║  ║  ║ └╥┘
#          pho_0.0  pho_1.0  pho_2.0  pho_3.0  │  pho_4.0 ┌───┐ pho_5.0  │P(-π/2)  pho_6.0  │P(-π/4)  pho_7.0   │P(-π/8)  pho_8.0            │P(-π/16)  pho_9.0                  │P(-π/32)  pho_10.0                       │P(-π/64)  pho_11.0                            │P(-π/128)   pho_12.0  pho_13.0   pho_14.0  pho_15.0  pho_16.0   pho_17.0  pho_18.0   pho_19.0  pho_20.0  pho_21.0  pho_22.0  pho_23.0  pho_24.0  pho_25.0  pho_26.0  pho_27.0  pho_28.0  pho_29.0  pho_30.0  pho_31.0  pho_32.0  pho_33.0  pho_34.0  pho_35.0  pho_36.0  pho_37.0  pho_38.0  pho_39.0  pho_40.0  ░  ║  ║  ║  ║  ║  ║  ║ ┌─┐
#    q_7: ────░────────░────────░────────░─────X─────░────┤ H ├────░─────■────────────░─────■────────────░──────■────────────░───────────────■─────────────░─────────────────────■─────────────░───────────────────────────■─────────────░────────────────────────────────■───────────────░─────────░──────────░─────────░─────────░──────────░─────────░──────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░─────────░──────░──╫──╫──╫──╫──╫──╫──╫─┤M├
#             ░        ░        ░        ░           ░    └───┘    ░                  ░                  ░                   ░                             ░                                   ░                                         ░                                                ░         ░          ░         ░         ░          ░         ░          ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░         ░      ░  ║  ║  ║  ║  ║  ║  ║ └╥┘
# meas_0: ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╬══╬══╬══╬══╬══╬══╬═
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ║  ║  ║  ║  ║  ║  ║
# meas_1: ════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╬══╬══╬══╬══╬══╬═
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ║  ║  ║  ║  ║  ║
# meas_2: ═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╬══╬══╬══╬══╬═
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ║  ║  ║  ║  ║
# meas_3: ══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╬══╬══╬══╬═
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ║  ║  ║  ║
# meas_4: ═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╬══╬══╬═
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ║  ║  ║
# meas_5: ════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╬══╬═
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ║  ║
# meas_6: ═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩══╬═
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ║
# meas_7: ══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╩═

# %%
plt.rc('figure', figsize=(12, 6))
params = {'text.usetex' : True, 'font.size' : 12, 'font.family' : 'serif'}
plt.rcParams.update(params)

#cmap = plt.get_cmap('twilight')
xs = []
for i in range(40):
    xs.append(i)
 
plt.xticks(xs)
plt.xlabel('Circuit Step')
plt.ylabel(r"$S(\rho^{(1)})$")

for i in range(2*n):
    color = cmap(i/(2*n))
    plt.plot(data[i], label=f'{i}')#, color = color)
plt.legend(fontsize = 15, title = 'Qubit')


#plt.savefig('qft_ent_partitionsSINGLE.pdf', format = 'pdf')

# %%
density_matrix
# Out:
# 0
