# %% [markdown]
# # SHOR with multiple errors (random pos.)

# %%
import qiskit.quantum_info as qi
from qiskit import Aer
from qiskit import execute, transpile, assemble
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit import QuantumCircuit, execute
from qiskit.providers.aer import QasmSimulator
from qiskit.extensions import UnitaryGate
from qiskit.quantum_info.operators import Operator
from qiskit.visualization import plot_state_city
from qiskit.visualization import plot_histogram
from qiskit.visualization import array_to_latex
from qiskit.providers.aer.library import SaveDensityMatrix
from qiskit.quantum_info import Statevector
from random import sample
import numpy as np
from numpy import linalg
from numpy import pi
from sympy import *
from sympy import factorint
from fractions import Fraction
import pandas as pd
import random
import math
import matplotlib.pyplot as plt
import pickle
#plt.rc('figure', figsize=(16, 6))

# %%
def check(number):
    if number % 2 == 0:
        print("Even, 2 is a divisor")
        return
        
    if isprime(number) == True:
        print("Prime number")
        return
    
    factorization = factorint(number)
    for i in range(len(factorization.keys())):
        p = list(factorization)[i]
        q = list(factorization.values())[i]
        if isprime(p) and q != 1:
            print("Prime Power: %i^%i, %i is a divisor" % ( p, q, p))
            return
    
    y = random.randrange(2, number - 1)
    a = math.gcd(y, number)
    if a > 1:
        print("Divisor: a = %i" %(a))
        return 
        
    else:
        print("y = %i and N = %i are coprime - r well defined" %  (y, N))
        return

# %%
def mod_exp(n, y, N, power):
    dim = 2**n
    matrix_0 = np.zeros((dim, dim))
    
    for i in range(N):
        j = (i*y)%N
        matrix_0[j][i]=1
             
    for ii in range(N, dim):
        matrix_0[ii][ii] = 1
             
    temp = matrix_0
    for iii in range(power):
        matrix = np.dot(temp, temp)
        temp = matrix
        
    U = UnitaryGate(temp)
    
    U.name = "%i^%i mod %i" % ( y, 2**power, N)
    c_U = U.control()
    return c_U

# %%
def qft_rotations(circuit, n, n_max,  case, position):
    tmp = n_max - case 
    if n == 0:
        return circuit
    n -= 1    

    if n  >=  tmp:   
        errori(circuit, position, n_max) 
        if n == tmp: 
            circuit.id(position)    
    circuit.h(n)   
    
    for qubit in range(n):
        circuit.cp(np.pi/2**(n-qubit), qubit, n)

    qft_rotations(circuit, n, n_max, case, position)

# %%
def swap_registers(circuit, n):
    
    for qubit in range(n//2):
        circuit.swap(qubit, n-qubit-1)

# %% [markdown]
# ## Error routine

# %%
def errori(circuit, position, n):
    epsilon = 0                                              
    extracted = random.uniform(0, 1)
    position = random.randint(0, n)
    
    if (extracted < epsilon):  
        circuit.x(position)   
    else:
        circuit.z(position)
    return circuit

# %%
def qft(circuit, n, n_max, case, position):
    qft_rotations(circuit, n, n_max, case, position)

    if case >= n + 1:
        errori(circuit, position, n_max)
        if case == n + 1:
            circuit.id(position)
        
    swap_registers(circuit, n)    

    if case >= n + 2:
        errori(circuit, position , n_max)
        if case == n + 2:
            circuit.id(position)
        
    if case >= 0:
        pass
        
    if case > n + 2:
        print('Error: case value incorrect')
    return circuit

# %%
#coprimes = [2, 4, 7, 8, 11, 13, 14] #----------------------------------------------
N = 21
repetitions = 1

plot = []
n = math.ceil(math.log(N,2))

for rep in range(repetitions):
    case = 0 #random.randint(0, n+2 + 1)
    y = 2#coprimes[random.randint(0, 6)]
    print(rep)
    position = random.randint(0, 2*n)
    
    control = QuantumRegister(2*n, 'r1')
    target  = QuantumRegister(n, 't1')
    classic = ClassicalRegister(2*n, 'c')
    circuit = QuantumCircuit(control, target, classic)
    circuit.h(range(2*n))
    circuit.x(2*n + n -1)

    for q in range(2*n):
        circuit.append(mod_exp(n, y, N, q),     
                 [q] + [i+2*n for i in range(n)])    
    circuit.save_density_matrix()

    qft(circuit, n, n, case, position)
    circuit.measure(range(2*n), range(2*n))        

    aer_sim = Aer.get_backend('aer_simulator')
    t_qc = transpile(circuit, aer_sim)
    qobj = assemble(t_qc)                             
    results = aer_sim.run(qobj,shots = 1).result()          

    counts = results.get_counts()
    density_matrix = results.data().get('density_matrix')
    labels = []
    for i in range(len(counts)):
        labels.append(   int(list(counts.keys())[i], 2 )   )
    new_counts = dict(zip(labels,list(counts.values()) ))
    density_matrix = np.asarray(density_matrix)

    n_count = 2*n
    rows, measured_phases = [], []
    for output in counts:
        decimal = int(output, 2)                       
        phase = decimal/(2**n_count)                   
        measured_phases.append(phase)
                                                       
        rows.append([f"{output}(bin) = {decimal:>3}(dec)", 
                     f"{decimal}/{2**n_count} = {phase:.2f}"])                                                      
    headers=["Register Output", "Phase"]
    df = pd.DataFrame(rows, columns=headers)

    rows = []
    period = []
    for phase in measured_phases:
        frac = Fraction(phase).limit_denominator(15)
        rows.append([phase, f"{frac.numerator}/{frac.denominator}", frac.denominator])
        period.append(frac.denominator)

    headers=["Phase", "Fraction", "Guess for r"]
    df = pd.DataFrame(rows, columns=headers)

    r = max(period)
    guesses = [gcd(y**(r//2)-1, N), gcd(y**(r//2)+1, N)]
    plot.append(guesses)
    
    print('case = ', case, 'fact = ',guesses)
    df = 0
    repetitions += 1
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\giuli\Desktop\tesi\PYTHON\ch8\shor_noisy_multiple_errors.ipynb Cell 10 in <cell line: 8>()
#      <a href='vscode-notebook-cell:/c%3A/Users/giuli/Desktop/tesi/PYTHON/ch8/shor_noisy_multiple_errors.ipynb#X12sZmlsZQ%3D%3D?line=26'>27</a> circuit.measure(range(2*n), range(2*n))
#      <a href='vscode-notebook-cell:/c%3A/Users/giuli/Desktop/tesi/PYTHON/ch8/shor_noisy_multiple_errors.ipynb#X12sZmlsZQ%3D%3D?line=28'>29</a> aer_sim = Aer.get_backend('aer_simulator')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/giuli/Desktop/tesi/PYTHON/ch8/shor_noisy_multiple_errors.ipynb#X12sZmlsZQ%3D%3D?line=29'>30</a> t_qc = transpile(circuit, aer_sim)
#      <a href='vscode-notebook-cell:/c%3A/Users/giuli/Desktop/tesi/PYTHON/ch8/shor_noisy_multiple_errors.ipynb#X12sZmlsZQ%3D%3D?line=30'>31</a> qobj = assemble(t_qc)
#      <a href='vscode-notebook-cell:/c%3A/Users/giuli/Desktop/tesi/PYTHON/ch8/shor_noisy_multiple_errors.ipynb#X12sZmlsZQ%3D%3D?line=31'>32</a> results = aer_sim.run(qobj,shots = 1).result()
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\compiler\transpiler.py:382, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     379     for circuit, unique_args in zip(circuits, unique_transpile_args):
#     380         transpile_config, pass_manager = _combine_args(shared_args, unique_args)
#     381         output_circuits.append(
# --> 382             _serial_transpile_circuit(
#     383                 circuit,
#     384                 pass_manager,
#     385                 transpile_config["callback"],
#     386                 transpile_config["output_name"],
#     387                 transpile_config["backend_num_qubits"],
#     388                 transpile_config["faulty_qubits_map"],
#     389                 transpile_config["pass_manager_config"].backend_properties,
#     390             )
#     391         )
#     392     circuits = output_circuits
#     393 end_time = time()
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\compiler\transpiler.py:475, in _serial_transpile_circuit(circuit, pass_manager, callback, output_name, num_qubits, faulty_qubits_map, backend_prop)
#     466 def _serial_transpile_circuit(
#     467     circuit,
#     468     pass_manager,
#    (...)
#     473     backend_prop=None,
#     474 ):
# --> 475     result = pass_manager.run(circuit, callback=callback, output_name=output_name)
#     476     if faulty_qubits_map:
#     477         return _remap_circuit_faulty_backend(
#     478             result,
#     479             num_qubits,
#     480             backend_prop,
#     481             faulty_qubits_map,
#     482         )
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\transpiler\passmanager.py:528, in StagedPassManager.run(self, circuits, output_name, callback)
#     521 def run(
#     522     self,
#     523     circuits: Union[QuantumCircuit, List[QuantumCircuit]],
#     524     output_name: str = None,
#     525     callback: Callable = None,
#     526 ) -> Union[QuantumCircuit, List[QuantumCircuit]]:
#     527     self._update_passmanager()
# --> 528     return super().run(circuits, output_name, callback)
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\transpiler\passmanager.py:228, in PassManager.run(self, circuits, output_name, callback)
#     226     return circuits
#     227 if isinstance(circuits, QuantumCircuit):
# --> 228     return self._run_single_circuit(circuits, output_name, callback)
#     229 if len(circuits) == 1:
#     230     return self._run_single_circuit(circuits[0], output_name, callback)
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\transpiler\passmanager.py:283, in PassManager._run_single_circuit(self, circuit, output_name, callback)
#     271 """Run all the passes on a ``circuit``.
#     272
#     273 Args:
#    (...)
#     280     The transformed circuit.
#     281 """
#     282 running_passmanager = self._create_running_passmanager()
# --> 283 result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     284 self.property_set = running_passmanager.property_set
#     285 return result
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\transpiler\runningpassmanager.py:125, in RunningPassManager.run(***failed resolving arguments***)
#     123 for passset in self.working_list:
#     124     for pass_ in passset:
# --> 125         dag = self._do_pass(pass_, dag, passset.options)
#     127 circuit = dag_to_circuit(dag)
#     128 if output_name:
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\transpiler\runningpassmanager.py:172, in RunningPassManager._do_pass(self, pass_, dag, options)
#     170 # Run the pass itself, if not already run
#     171 if pass_ not in self.valid_passes:
# --> 172     dag = self._run_this_pass(pass_, dag)
#     174     # update the valid_passes property
#     175     self._update_valid_passes(pass_)
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\transpiler\runningpassmanager.py:201, in RunningPassManager._run_this_pass(self, pass_, dag)
#     198 if pass_.is_transformation_pass:
#     199     # Measure time if we have a callback or logging set
#     200     start_time = time()
# --> 201     new_dag = pass_.run(dag)
#     202     end_time = time()
#     203     run_time = end_time - start_time
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\transpiler\passes\utils\control_flow.py:56, in trivial_recurse.<locals>.out(self, dag)
#      54 for node in dag.op_nodes(ControlFlowOp):
#      55     node.op = map_blocks(bound_wrapped_method, node.op)
# ---> 56 return method(self, dag)
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_decomposition.py:170, in Optimize1qGatesDecomposition.run(self, dag)
#     167     if "u2" not in self._target_basis and "u1" not in self._target_basis:
#     168         continue
# --> 170 new_basis, new_circ = self._resynthesize_run(run)
#     172 if new_circ is not None and self._substitution_checks(dag, run, new_circ, new_basis):
#     173     new_dag = circuit_to_dag(new_circ)
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_decomposition.py:79, in Optimize1qGatesDecomposition._resynthesize_run(self, run)
#      76 for gate in run[1:]:
#      77     operator = gate.op.to_matrix().dot(operator)
# ---> 79 new_circs = {k: v._decompose(operator) for k, v in self._decomposers.items()}
#      81 new_basis, new_circ = None, None
#      82 if len(new_circs) > 0:
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\transpiler\passes\optimization\optimize_1q_decomposition.py:79, in <dictcomp>(.0)
#      76 for gate in run[1:]:
#      77     operator = gate.op.to_matrix().dot(operator)
# ---> 79 new_circs = {k: v._decompose(operator) for k, v in self._decomposers.items()}
#      81 new_basis, new_circ = None, None
#      82 if len(new_circs) > 0:
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\quantum_info\synthesis\one_qubit_decompose.py:166, in OneQubitEulerDecomposer._decompose(self, unitary, simplify, atol)
#     165 def _decompose(self, unitary, simplify=True, atol=DEFAULT_ATOL):
# --> 166     theta, phi, lam, phase = self._params(unitary)
#     167     circuit = self._circuit(theta, phi, lam, phase, simplify=simplify, atol=atol)
#     168     return circuit
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\quantum_info\synthesis\one_qubit_decompose.py:276, in OneQubitEulerDecomposer._params_xzx(umat)
#     274 mat = umat / np.sqrt(det)
#     275 mat_zxz = _h_conjugate(mat)
# --> 276 theta, phi, lam, phase_zxz = OneQubitEulerDecomposer._params_zxz(mat_zxz)
#     277 return theta, phi, lam, phase + phase_zxz
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\quantum_info\synthesis\one_qubit_decompose.py:245, in OneQubitEulerDecomposer._params_zxz(mat)
#     242 @staticmethod
#     243 def _params_zxz(mat):
#     244     """Return the Euler angles and phase for the ZXZ basis."""
# --> 245     theta, phi, lam, phase = OneQubitEulerDecomposer._params_zyz(mat)
#     246     return theta, phi + np.pi / 2, lam - np.pi / 2, phase
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\qiskit\quantum_info\synthesis\one_qubit_decompose.py:227, in OneQubitEulerDecomposer._params_zyz(mat)
#     223 import scipy.linalg as la
#     225 # We rescale the input matrix to be special unitary (det(U) = 1)
#     226 # This ensures that the quaternion representation is real
# --> 227 coeff = la.det(mat) ** (-0.5)
#     228 phase = -cmath.phase(coeff)
#     229 su_mat = coeff * mat  # U in SU(2)
#
# File c:\Users\giuli\anaconda3\envs\quiskit\lib\site-packages\scipy\linalg\_basic.py:1016, in det(a, overwrite_a, check_finite)
#    1014 overwrite_a = overwrite_a or _datacopied(a1, a)
#    1015 fdet, = get_flinalg_funcs(('det',), (a1,))
# -> 1016 a_det, info = fdet(a1, overwrite_a=overwrite_a)
#    1017 if info < 0:
#    1018     raise ValueError('illegal value in %d-th argument of internal '
#    1019                      'det.getrf' % -info)
#
# KeyboardInterrupt:

# %%
labels = [[1,3], [3,1], [3,5], [5,3], [15,1], [1,15] ]
counts = [0, 0, 0, 0, 0, 0]
frequencies = np.zeros(len(counts))
data = plot
color_bars = '#4C495A'

for i in range(len(data)):
    for ii in range(len(labels)):
        if data[i] == labels[ii]:
            counts[ii] += 1
           
for i in range(len(counts)): 
    frequencies[i] = counts[i]/repetitions

frequenciesBIS = np.zeros(3)

repetitions = 5    #--------------------------------------------------------------------------------
for i in range(len(frequenciesBIS)):
    #for i in range(ii, len(counts), 2):
    frequenciesBIS[i] = (counts[2*i] + counts[2*i+ 1])/repetitions
    
print(frequenciesBIS)

freq_series = pd.Series(frequenciesBIS)
names = ('[1,3]', '[3,5]', '[1,15]')

fig = freq_series.plot(kind='bar', color = color_bars)
fig.set_xlabel("Factorization")
fig.set_ylabel('Frequency')
fig.set_xticklabels(names, rotation = 0)
params = {'text.usetex' : True, 'font.size' : 20, 'font.family' : 'serif'}
plt.rcParams.update(params)
plt.tight_layout()

print(case, counts)

#plt.savefig('shor_multiple_ideal_qft.pdf', format = 'pdf') 
#pickle.dump(frequencies, open('shor_noisy_multiple_errors.pkl', 'wb'))
# Out:
# 5 [48, 52, 98, 24, 107, 21]

# %%
coprimes = [2, 4, 7, 8, 11, 13, 14]
y = coprimes[random.randint(0, 6)]
print(type(y))
# Out:
# <class 'int'>
